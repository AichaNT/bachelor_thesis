# %%
import os
import pandas as pd
from pybtex.database import parse_file
from scripts.data_preprocess import bib_to_csv

# %%
#paths
path = "data/raw/manual_search/ScienceDirect/sd_query_2026-03-02.bib"
csv_path = "data/processed/sd_query_2026-0302.csv"

# %%
sd = bib_to_csv(path, csv_path)
