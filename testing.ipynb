# %%
import os
import pandas as pd
from pybtex.database import parse_file
from scripts.data_preprocess import bib_to_csv
from scripts.data_fetch import fetch_metadata
from dotenv import load_dotenv
import springernature_api_client.meta as meta

# %%
#paths fetch_metadata(inupt_path, output_path, column_name, client, path_fetched_dois, daily_limit = 450)
input_paths = ["data/raw/manual_search/Springer/springer_query_-2024_2026-03-02.csv", "data/raw/manual_search/Springer/springer_query_2025-2026_2026-03-02.csv"]
output_path = "data/raw/API_search/springer_api_metadata.JSON"
column_name = "Item DOI"
path_fetched_dois = "data/processed/fetched_dois.csv"

# %%
# Load .env file
load_dotenv()

# Access the API key
SPRINGER_API_KEY = os.getenv("SPRINGER_API_KEY")

if not SPRINGER_API_KEY:
    raise ValueError("Springer API key not found. Make sure .env exists and contains SPRINGER_API_KEY")

# %%
# initialize API Client
client = meta.MetaAPI(api_key = SPRINGER_API_KEY)

# %%
#fetch_metadata(input_paths, output_path, column_name, client, path_fetched_dois)
# Out:
# 2026-03-03 14:24:29,648 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10676-020-09568-6', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10676-020-09568-6', page=10, start=1
# 2026-03-03 14:24:30,398 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s00521-022-07136-1', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s00521-022-07136-1', page=10, start=1
# 2026-03-03 14:24:31,898 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1186/s13677-022-00355-w', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1186/s13677-022-00355-w', page=10, start=1
# 2026-03-03 14:24:33,686 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s11042-022-13252-w', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s11042-022-13252-w', page=10, start=1
# 2026-03-03 14:24:34,405 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s11416-021-00391-1', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s11416-021-00391-1', page=10, start=1
# 2026-03-03 14:24:35,074 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s43681-021-00039-2', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s43681-021-00039-2', page=10, start=1
# 2026-03-03 14:24:35,786 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10844-024-00894-5', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10844-024-00894-5', page=10, start=1
# 2026-03-03 14:24:36,451 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1186/s13677-024-00663-3', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1186/s13677-024-00663-3', page=10, start=1
# 2026-03-03 14:24:37,169 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10462-023-10666-2', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10462-023-10666-2', page=10, start=1
# 2026-03-03 14:24:38,162 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1186/s41239-020-00192-4', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1186/s41239-020-00192-4', page=10, start=1
# 2026-03-03 14:24:39,014 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1140/epjds/s13688-024-00467-0', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1140/epjds/s13688-024-00467-0', page=10, start=1
# 2026-03-03 14:24:39,719 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s43681-022-00171-7', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s43681-022-00171-7', page=10, start=1
# 2026-03-03 14:24:40,450 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s42979-024-03055-1', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s42979-024-03055-1', page=10, start=1
# 2026-03-03 14:24:41,163 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s00146-023-01789-9', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s00146-023-01789-9', page=10, start=1
# 2026-03-03 14:24:42,188 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1186/s13677-020-00187-6', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1186/s13677-020-00187-6', page=10, start=1
# 2026-03-03 14:24:42,902 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10462-024-10818-y', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10462-024-10818-y', page=10, start=1
# 2026-03-03 14:24:43,619 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1186/s40537-023-00876-4', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1186/s40537-023-00876-4', page=10, start=1
# 2026-03-03 14:24:44,441 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s11432-021-3487-x', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s11432-021-3487-x', page=10, start=1
# 2026-03-03 14:24:45,257 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10462-023-10521-4', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10462-023-10521-4', page=10, start=1
# 2026-03-03 14:24:45,974 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10664-023-10417-5', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10664-023-10417-5', page=10, start=1
# 2026-03-03 14:24:46,692 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s43681-021-00081-0', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s43681-021-00081-0', page=10, start=1
# 2026-03-03 14:24:47,369 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s11432-021-3354-7', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s11432-021-3354-7', page=10, start=1
# 2026-03-03 14:24:48,008 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10462-024-10962-5', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10462-024-10962-5', page=10, start=1
# 2026-03-03 14:24:48,676 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1186/s13677-020-00215-5', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1186/s13677-020-00215-5', page=10, start=1
# 2026-03-03 14:24:49,380 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10115-022-01753-x', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10115-022-01753-x', page=10, start=1
# 2026-03-03 14:24:50,177 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1186/s42162-022-00245-0', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1186/s42162-022-00245-0', page=10, start=1
# 2026-03-03 14:24:50,811 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10462-022-10246-w', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10462-022-10246-w', page=10, start=1
# 2026-03-03 14:24:51,670 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1186/s42162-024-00330-6', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1186/s42162-024-00330-6', page=10, start=1
# 2026-03-03 14:24:52,424 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10462-024-10948-3', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10462-024-10948-3', page=10, start=1
# 2026-03-03 14:24:53,132 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10515-024-00458-5', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10515-024-00458-5', page=10, start=1
# 2026-03-03 14:24:53,774 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s42979-024-02737-0', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s42979-024-02737-0', page=10, start=1
# 2026-03-03 14:24:54,474 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10462-024-10836-w', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10462-024-10836-w', page=10, start=1
# 2026-03-03 14:24:55,210 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10462-024-10971-4', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10462-024-10971-4', page=10, start=1
# 2026-03-03 14:24:55,840 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s00146-020-01045-4', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s00146-020-01045-4', page=10, start=1
# 2026-03-03 14:24:56,623 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s00138-023-01475-2', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s00138-023-01475-2', page=10, start=1
# 2026-03-03 14:24:57,420 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s11704-024-3853-2', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s11704-024-3853-2', page=10, start=1
# 2026-03-03 14:24:58,262 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10515-024-00434-z', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10515-024-00434-z', page=10, start=1
# 2026-03-03 14:24:59,021 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s11042-022-14075-5', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s11042-022-14075-5', page=10, start=1
# 2026-03-03 14:24:59,698 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/978-3-031-25803-9_7', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/978-3-031-25803-9_7', page=10, start=1
# 2026-03-03 14:25:00,385 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10462-024-11040-6', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10462-024-11040-6', page=10, start=1
# 2026-03-03 14:25:01,130 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10462-023-10449-9', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10462-023-10449-9', page=10, start=1
# 2026-03-03 14:25:01,743 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s00146-022-01613-w', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s00146-022-01613-w', page=10, start=1
# 2026-03-03 14:25:02,428 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s42979-024-02953-8', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s42979-024-02953-8', page=10, start=1
# 2026-03-03 14:25:03,175 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s00521-023-08819-z', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s00521-023-08819-z', page=10, start=1
# 2026-03-03 14:25:03,897 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/978-3-031-09593-1_21', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/978-3-031-09593-1_21', page=10, start=1
# 2026-03-03 14:25:04,530 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10462-024-10840-0', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10462-024-10840-0', page=10, start=1
# 2026-03-03 14:25:05,227 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s10111-022-00711-5', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s10111-022-00711-5', page=10, start=1
# 2026-03-03 14:25:05,944 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s11432-021-3470-1', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s11432-021-3470-1', page=10, start=1
# 2026-03-03 14:25:06,602 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1140/epjds/s13688-023-00396-4', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1140/epjds/s13688-023-00396-4', page=10, start=1
# 2026-03-03 14:25:07,271 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s13218-022-00763-9', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s13218-022-00763-9', page=10, start=1
# 2026-03-03 14:25:08,109 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1365/s43439-022-00056-9', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1365/s43439-022-00056-9', page=10, start=1
# 2026-03-03 14:25:08,809 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1007/s11192-022-04503-6', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1007/s11192-022-04503-6', page=10, start=1
# 2026-03-03 14:25:09,497 - INFO - Making request to: https://api.springernature.com/meta/v2/json with params: {'q': '10.1186/s13677-023-00418-6', 'p': 10, 's': 1, 'api_key': '9a7f05d813a72418537730d30f9d874c'}
# Fetching meta: query='10.1186/s13677-023-00418-6', page=10, start=1
# 2026-03-03 14:25:09,733 - WARNING - Rate limit hit. Retrying in 38091 seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 fetch_metadata(input_paths, output_path, column_name, client, path_fetched_dois)
#
# File ~/Documents/GitHub/bachelor_thesis/scripts/data_fetch.py:54, in fetch_metadata(input_paths, output_path, column_name, client, path_fetched_dois, daily_limit)
#      51     break
#      53 try:
# ---> 54     response = client.search(doi)
#      56     if response:
#      57         json.dump(response, json_file)
#
# File /Applications/anaconda3/envs/thesis/lib/python3.11/site-packages/springernature_api_client/meta.py:21, in MetaAPI.search(self, q, p, s, fetch_all, is_premium)
#      18 while s <= (500 if is_premium else 100):
#      19     print(f"Fetching meta: query='{q}', page={p}, start={s}")
# ---> 21     response = self._make_request("meta/v2/json", q=q, p=p, s=s)
#      23     if response and "records" in response:
#      24         all_results.extend(response["records"])
#
# File /Applications/anaconda3/envs/thesis/lib/python3.11/site-packages/springernature_api_client/api_client.py:42, in SpringerNatureAPI._make_request(self, endpoint, fetch_all, is_tdm, **params)
#      40 wait_time = min(self.backoff_factor * (2 ** retries) + random.uniform(0, 1), 60)
#      41 logger.warning(f"Rate limit hit. Retrying in {retry_after} seconds...")
# ---> 42 time.sleep(retry_after)
#      43 retries += 1
#      44 continue  # Retry request after delay
#
# KeyboardInterrupt:
