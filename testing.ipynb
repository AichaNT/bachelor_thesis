# %%
import os
import pandas as pd
from pybtex.database import parse_file
from scripts.data_preprocess import bib_to_csv

# %%
#paths
acm1_path = "data/raw/manual_search/ACM/acm_query_abstract_2026-03-02.bib"
acm2_path = "data/raw/manual_search/ACM/acm_query_title_2026-03-02.bib"

# %%
paths = [acm1_path, acm2_path]
csv_path = "data/processed/acm_query_combined_2026-0302.csv"

acm = bib_to_csv(paths, csv_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 4
#       1 paths = [acm1_path, acm2_path]
#       2 csv_path = "data/processed/acm_query_combined_2026-0302.csv"
# ----> 4 acm = bib_to_csv(paths, csv_path)
#
# File ~/Documents/GitHub/bachelor_thesis/scripts/data_preprocess.py:15, in bib_to_csv(bib_paths, csv_output_path)
#      12 for path in bib_paths:
#      13     bib_data = parse_file(path)
# ---> 15     for key, entry in bib_data.entries:
#      16         record = {}
#      18         for col, val in entry.fields:
#
# ValueError: too many values to unpack (expected 2)
